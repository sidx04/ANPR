# %%
# !pip install easyocr
# !pip install imutils
# Out:
# Requirement already satisfied: easyocr in d:\anaconda\lib\site-packages (1.6.2)
# Requirement already satisfied: torch in d:\anaconda\lib\site-packages (from easyocr) (1.13.1)
# Requirement already satisfied: Pillow in d:\anaconda\lib\site-packages (from easyocr) (9.2.0)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from easyocr) (1.21.5)
# Requirement already satisfied: Shapely in d:\anaconda\lib\site-packages (from easyocr) (2.0.0)
# Requirement already satisfied: scikit-image in d:\anaconda\lib\site-packages (from easyocr) (0.19.2)
# Requirement already satisfied: python-bidi in d:\anaconda\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: torchvision>=0.5 in d:\anaconda\lib\site-packages (from easyocr) (0.14.1)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in d:\anaconda\lib\site-packages (from easyocr) (4.5.4.60)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from easyocr) (1.9.1)
# Requirement already satisfied: ninja in d:\anaconda\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: PyYAML in d:\anaconda\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: pyclipper in d:\anaconda\lib\site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from torchvision>=0.5->easyocr) (4.3.0)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in d:\anaconda\lib\site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: networkx>=2.2 in d:\anaconda\lib\site-packages (from scikit-image->easyocr) (2.8.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in d:\anaconda\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in d:\anaconda\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.14)
# Requirement already satisfied: imutils in d:\anaconda\lib\site-packages (0.5.4)

# %%
import cv2
from matplotlib import pyplot as plt

# %%
import imutils
import easyocr
import numpy as np

# %% [markdown]
# 1. Read in  Image (Greyscale)

# %%
img = cv2.imread('img3.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %% [markdown]
# 2. Filter and Find Edges for Localilsation

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %% [markdown]
# 3. Contour Search and Masking

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[868, 529]],
#
#        [[703, 535]],
#
#        [[698, 581]],
#
#        [[865, 571]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# 4. Reading Text with OCR

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[12, 1], [171, 1], [171, 53], [12, 53]], 'MH 12 62283', 0.4396034178135408)]

# %% [markdown]
# 5. Final Rendering

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1,color=(0,255,255), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
